# %%
import os
import pandas as pd

#import Complete_Concat_Identified.csv 
masterdf = pd.read_csv("/Users/izzywells/Desktop/Complete_Concat_Identified.csv")
acc= 0
for row in masterdf: 
    if acc == 1: 
        break
    print(row)
# Out:
# Class_ID
# EndDate_PRE
# EndDate_POST
# FG_Statu_PRE
# FG_Statu_POST
# NormScore_PRE
# NormScore_POST
# TotalScores_POST
# TotalScores_PRE
# Q148
# Q148_4_TEXT_PRE
# Q148_4_TEXT_POST
# Q148_PRE
# Q148_POST
# Q152_11
# Q152_11_TEXT
# Q152_11_TEXT_PRE
# Q152_11_TEXT_POST
# Q152_11_PRE
# Q152_11_POST
# Q152_21
# Q152_21_PRE
# Q152_21_POST
# Q152_23
# Q152_23_PRE
# Q152_23_POST
# Q152_25
# Q152_25_PRE
# Q152_25_POST
# Q152_39
# Q152_39_PRE
# Q152_39_POST
# Q153_11
# Q153_11_TEXT
# Q153_11_TEXT_PRE
# Q153_11_TEXT_POST
# Q153_11_PRE
# Q153_11_POST
# Q153_3
# Q153_3_PRE
# Q153_3_POST
# Q153_47
# Q153_47_PRE
# Q153_47_POST
# Q153_8
# Q153_8_PRE
# Q153_8_POST
# Q154_11
# Q154_11_TEXT
# Q154_11_TEXT_PRE
# Q154_11_TEXT_POST
# Q154_11_PRE
# Q154_11_POST
# Q154_3
# Q154_3_PRE
# Q154_3_POST
# Q154_8
# Q154_8_PRE
# Q154_8_POST
# Q158_5_TEXT_PRE
# Q158_5_TEXT_POST
# Q158_PRE
# Q158_POST
# Q1B_PRE
# Q1B_POST
# Q1E_PRE
# Q1E_POST
# Q1b_19_TEXT_PRE
# Q1b_19_TEXT_POST
# Q1b_19_PRE
# Q1b_19_POST
# ...
